# %%
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
# Create dummy data
from sklearn.datasets.samples_generator import make_blobs

x_data, _ = make_blobs(n_samples=500, centers=6,
                       cluster_std=0.70, random_state=0)

# %%
# Plot and show scatter
plt.scatter(x_data[:, 0], x_data[:, 1])

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=12)
kmeans.fit(x_data)
predicted_clusters = kmeans.predict(x_data)

# %%
plt.scatter(x_data[:, 0], x_data[:, 1], c=predicted_clusters, s=50, cmap='Paired')

# %%
# Bonus
centers = kmeans.cluster_centers_
labels = kmeans.labels_

# %%
centers
# Out:
# array([[ 1.95128356,  0.83814653],
#        [-1.03103707,  8.21383008],
#        [ 9.10996446, -2.84369036],
#        [-2.04445909,  2.42695758],
#        [ 5.58467358,  1.15979841],
#        [ 1.64105791,  4.48825941],
#        [ 0.26379846,  5.12847713],
#        [-1.76536428,  7.34529214],
#        [-1.02458967,  3.23018497],
#        [ 0.62504333,  3.76827165],
#        [ 6.06709823,  0.10580353],
#        [ 9.47638047, -1.75019425]])

# %%
plt.scatter(x_data[:, 0], x_data[:, 1], c=labels, s=50, cmap='Paired')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)
